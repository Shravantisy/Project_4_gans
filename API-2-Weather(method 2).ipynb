# %%
import pandas as pd
import requests
from datetime import datetime
import pytz

# %%
#city name and url
city = 'Berlin'
API_key = 'APIKEY'

# check out the docs for more info on making an api call https://openweathermap.org/forecast5
url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric")

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
json = response.json()
json
# Out:
# {'city': {'coord': {'lat': 52.5244, 'lon': 13.4105},
#   'country': 'DE',
#   'id': 2950159,
#   'name': 'Berlin',
#   'population': 1000000,
#   'sunrise': 1657248804,
#   'sunset': 1657308539,
#   'timezone': 7200},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 75},
#    'dt': 1657281600,
#    'dt_txt': '2022-07-08 12:00:00',
#    'main': {'feels_like': 20.23,
#     'grnd_level': 1019,
#     'humidity': 64,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'temp': 20.46,
#     'temp_kf': -1.97,
#     'temp_max': 22.43,
#     'temp_min': 20.46},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 308, 'gust': 8.35, 'speed': 6.58}},
#   {'clouds': {'all': 83},
#    'dt': 1657292400,
#    'dt_txt': '2022-07-08 15:00:00',
#    'main': {'feels_like': 19.59,
#     'grnd_level': 1020,
#     'humidity': 65,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'temp': 19.85,
#     'temp_kf': 1.23,
#     'temp_max': 19.85,
#     'temp_min': 18.62},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 309, 'gust': 7.91, 'speed': 4.67}},
#   {'clouds': {'all': 80},
#    'dt': 1657303200,
#    'dt_txt': '2022-07-08 18:00:00',
#    'main': {'feels_like': 19.55,
#     'grnd_level': 1019,
#     'humidity': 61,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 19.91,
#     'temp_kf': 0.28,
#     'temp_max': 19.91,
#     'temp_min': 19.63},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 264, 'gust': 7.39, 'speed': 4.2}},
#   {'clouds': {'all': 49},
#    'dt': 1657314000,
#    'dt_txt': '2022-07-08 21:00:00',
#    'main': {'feels_like': 15.88,
#     'grnd_level': 1019,
#     'humidity': 66,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'temp': 16.46,
#     'temp_kf': 0,
#     'temp_max': 16.46,
#     'temp_min': 16.46},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03n',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 295, 'gust': 9.24, 'speed': 3.47}},
#   {'clouds': {'all': 39},
#    'dt': 1657324800,
#    'dt_txt': '2022-07-09 00:00:00',
#    'main': {'feels_like': 13.13,
#     'grnd_level': 1019,
#     'humidity': 78,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'temp': 13.67,
#     'temp_kf': 0,
#     'temp_max': 13.67,
#     'temp_min': 13.67},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03n',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 290, 'gust': 9.44, 'speed': 3.68}},
#   {'clouds': {'all': 27},
#    'dt': 1657335600,
#    'dt_txt': '2022-07-09 03:00:00',
#    'main': {'feels_like': 11.33,
#     'grnd_level': 1019,
#     'humidity': 90,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'temp': 11.75,
#     'temp_kf': 0,
#     'temp_max': 11.75,
#     'temp_min': 11.75},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 285, 'gust': 9.02, 'speed': 3.57}},
#   {'clouds': {'all': 47},
#    'dt': 1657346400,
#    'dt_txt': '2022-07-09 06:00:00',
#    'main': {'feels_like': 13.5,
#     'grnd_level': 1018,
#     'humidity': 81,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'temp': 13.94,
#     'temp_kf': 0,
#     'temp_max': 13.94,
#     'temp_min': 13.94},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 265, 'gust': 7.11, 'speed': 3.74}},
#   {'clouds': {'all': 100},
#    'dt': 1657357200,
#    'dt_txt': '2022-07-09 09:00:00',
#    'main': {'feels_like': 17.08,
#     'grnd_level': 1017,
#     'humidity': 68,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'temp': 17.5,
#     'temp_kf': 0,
#     'temp_max': 17.5,
#     'temp_min': 17.5},
#    'pop': 0.18,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 270, 'gust': 8.18, 'speed': 5.36}},
#   {'clouds': {'all': 100},
#    'dt': 1657368000,
#    'dt_txt': '2022-07-09 12:00:00',
#    'main': {'feels_like': 18.35,
#     'grnd_level': 1015,
#     'humidity': 69,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'temp': 18.63,
#     'temp_kf': 0,
#     'temp_max': 18.63,
#     'temp_min': 18.63},
#    'pop': 0.55,
#    'rain': {'3h': 0.81},
#    'sys': {'pod': 'd'},
#    'visibility': 9232,
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 286, 'gust': 8.75, 'speed': 5.37}},
#   {'clouds': {'all': 70},
#    'dt': 1657378800,
#    'dt_txt': '2022-07-09 15:00:00',
#    'main': {'feels_like': 20.25,
#     'grnd_level': 1014,
#     'humidity': 55,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 20.69,
#     'temp_kf': 0,
#     'temp_max': 20.69,
#     'temp_min': 20.69},
#    'pop': 0.98,
#    'rain': {'3h': 1.82},
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 284, 'gust': 10.1, 'speed': 5.17}},
#   {'clouds': {'all': 61},
#    'dt': 1657389600,
#    'dt_txt': '2022-07-09 18:00:00',
#    'main': {'feels_like': 18.06,
#     'grnd_level': 1014,
#     'humidity': 50,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 18.82,
#     'temp_kf': 0,
#     'temp_max': 18.82,
#     'temp_min': 18.82},
#    'pop': 0.81,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 318, 'gust': 10.54, 'speed': 6.03}},
#   {'clouds': {'all': 15},
#    'dt': 1657400400,
#    'dt_txt': '2022-07-09 21:00:00',
#    'main': {'feels_like': 13.95,
#     'grnd_level': 1014,
#     'humidity': 61,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 14.82,
#     'temp_kf': 0,
#     'temp_max': 14.82,
#     'temp_min': 14.82},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'few clouds',
#      'icon': '02n',
#      'id': 801,
#      'main': 'Clouds'}],
#    'wind': {'deg': 308, 'gust': 9.88, 'speed': 5.42}},
#   {'clouds': {'all': 27},
#    'dt': 1657411200,
#    'dt_txt': '2022-07-10 00:00:00',
#    'main': {'feels_like': 12.99,
#     'grnd_level': 1013,
#     'humidity': 65,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 13.85,
#     'temp_kf': 0,
#     'temp_max': 13.85,
#     'temp_min': 13.85},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03n',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 278, 'gust': 9.76, 'speed': 5.2}},
#   {'clouds': {'all': 100},
#    'dt': 1657422000,
#    'dt_txt': '2022-07-10 03:00:00',
#    'main': {'feels_like': 12.1,
#     'grnd_level': 1013,
#     'humidity': 71,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 12.9,
#     'temp_kf': 0,
#     'temp_max': 12.9,
#     'temp_min': 12.9},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 286, 'gust': 10.75, 'speed': 5.56}},
#   {'clouds': {'all': 100},
#    'dt': 1657432800,
#    'dt_txt': '2022-07-10 06:00:00',
#    'main': {'feels_like': 12.41,
#     'grnd_level': 1013,
#     'humidity': 68,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 13.25,
#     'temp_kf': 0,
#     'temp_max': 13.25,
#     'temp_min': 13.25},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 287, 'gust': 10.5, 'speed': 5.83}},
#   {'clouds': {'all': 93},
#    'dt': 1657443600,
#    'dt_txt': '2022-07-10 09:00:00',
#    'main': {'feels_like': 15.12,
#     'grnd_level': 1013,
#     'humidity': 56,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 16,
#     'temp_kf': 0,
#     'temp_max': 16,
#     'temp_min': 16},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 299, 'gust': 8.22, 'speed': 6.42}},
#   {'clouds': {'all': 96},
#    'dt': 1657454400,
#    'dt_txt': '2022-07-10 12:00:00',
#    'main': {'feels_like': 16.61,
#     'grnd_level': 1013,
#     'humidity': 49,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 17.52,
#     'temp_kf': 0,
#     'temp_max': 17.52,
#     'temp_min': 17.52},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 291, 'gust': 8.28, 'speed': 6.3}},
#   {'clouds': {'all': 99},
#    'dt': 1657465200,
#    'dt_txt': '2022-07-10 15:00:00',
#    'main': {'feels_like': 16.46,
#     'grnd_level': 1013,
#     'humidity': 53,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 17.29,
#     'temp_kf': 0,
#     'temp_max': 17.29,
#     'temp_min': 17.29},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 284, 'gust': 8.29, 'speed': 6.55}},
#   {'clouds': {'all': 96},
#    'dt': 1657476000,
#    'dt_txt': '2022-07-10 18:00:00',
#    'main': {'feels_like': 15.91,
#     'grnd_level': 1013,
#     'humidity': 58,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 16.67,
#     'temp_kf': 0,
#     'temp_max': 16.67,
#     'temp_min': 16.67},
#    'pop': 0.01,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 279, 'gust': 8.13, 'speed': 5.35}},
#   {'clouds': {'all': 91},
#    'dt': 1657486800,
#    'dt_txt': '2022-07-10 21:00:00',
#    'main': {'feels_like': 14.36,
#     'grnd_level': 1013,
#     'humidity': 68,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 15.03,
#     'temp_kf': 0,
#     'temp_max': 15.03,
#     'temp_min': 15.03},
#    'pop': 0.12,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04n',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 284, 'gust': 11.2, 'speed': 5.04}},
#   {'clouds': {'all': 54},
#    'dt': 1657497600,
#    'dt_txt': '2022-07-11 00:00:00',
#    'main': {'feels_like': 12.08,
#     'grnd_level': 1013,
#     'humidity': 79,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 12.69,
#     'temp_kf': 0,
#     'temp_max': 12.69,
#     'temp_min': 12.69},
#    'pop': 0.03,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 291, 'gust': 9.82, 'speed': 4.13}},
#   {'clouds': {'all': 78},
#    'dt': 1657508400,
#    'dt_txt': '2022-07-11 03:00:00',
#    'main': {'feels_like': 11.68,
#     'grnd_level': 1013,
#     'humidity': 82,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 12.26,
#     'temp_kf': 0,
#     'temp_max': 12.26,
#     'temp_min': 12.26},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 290, 'gust': 9.13, 'speed': 3.91}},
#   {'clouds': {'all': 74},
#    'dt': 1657519200,
#    'dt_txt': '2022-07-11 06:00:00',
#    'main': {'feels_like': 13.8,
#     'grnd_level': 1013,
#     'humidity': 73,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 14.4,
#     'temp_kf': 0,
#     'temp_max': 14.4,
#     'temp_min': 14.4},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 296, 'gust': 7.59, 'speed': 4.33}},
#   {'clouds': {'all': 89},
#    'dt': 1657530000,
#    'dt_txt': '2022-07-11 09:00:00',
#    'main': {'feels_like': 19.08,
#     'grnd_level': 1013,
#     'humidity': 46,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 19.84,
#     'temp_kf': 0,
#     'temp_max': 19.84,
#     'temp_min': 19.84},
#    'pop': 0.27,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 304, 'gust': 6.16, 'speed': 4.79}},
#   {'clouds': {'all': 90},
#    'dt': 1657540800,
#    'dt_txt': '2022-07-11 12:00:00',
#    'main': {'feels_like': 19.49,
#     'grnd_level': 1013,
#     'humidity': 45,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 20.24,
#     'temp_kf': 0,
#     'temp_max': 20.24,
#     'temp_min': 20.24},
#    'pop': 0.33,
#    'rain': {'3h': 0.25},
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 311, 'gust': 6.51, 'speed': 4.25}},
#   {'clouds': {'all': 93},
#    'dt': 1657551600,
#    'dt_txt': '2022-07-11 15:00:00',
#    'main': {'feels_like': 20.37,
#     'grnd_level': 1013,
#     'humidity': 43,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 21.08,
#     'temp_kf': 0,
#     'temp_max': 21.08,
#     'temp_min': 21.08},
#    'pop': 0.04,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 317, 'gust': 6.5, 'speed': 4.92}},
#   {'clouds': {'all': 86},
#    'dt': 1657562400,
#    'dt_txt': '2022-07-11 18:00:00',
#    'main': {'feels_like': 19.08,
#     'grnd_level': 1013,
#     'humidity': 48,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 19.79,
#     'temp_kf': 0,
#     'temp_max': 19.79,
#     'temp_min': 19.79},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 315, 'gust': 5, 'speed': 2.39}},
#   {'clouds': {'all': 89},
#    'dt': 1657573200,
#    'dt_txt': '2022-07-11 21:00:00',
#    'main': {'feels_like': 15.22,
#     'grnd_level': 1014,
#     'humidity': 60,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 16,
#     'temp_kf': 0,
#     'temp_max': 16,
#     'temp_min': 16},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04n',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 314, 'gust': 6.2, 'speed': 2.49}},
#   {'clouds': {'all': 57},
#    'dt': 1657584000,
#    'dt_txt': '2022-07-12 00:00:00',
#    'main': {'feels_like': 13.27,
#     'grnd_level': 1014,
#     'humidity': 67,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'temp': 14.06,
#     'temp_kf': 0,
#     'temp_max': 14.06,
#     'temp_min': 14.06},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04n',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 300, 'gust': 6.68, 'speed': 2.73}},
#   {'clouds': {'all': 1},
#    'dt': 1657594800,
#    'dt_txt': '2022-07-12 03:00:00',
#    'main': {'feels_like': 12.06,
#     'grnd_level': 1015,
#     'humidity': 76,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'temp': 12.75,
#     'temp_kf': 0,
#     'temp_max': 12.75,
#     'temp_min': 12.75},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 290, 'gust': 7.09, 'speed': 2.79}},
#   {'clouds': {'all': 6},
#    'dt': 1657605600,
#    'dt_txt': '2022-07-12 06:00:00',
#    'main': {'feels_like': 15.97,
#     'grnd_level': 1015,
#     'humidity': 69,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'temp': 16.47,
#     'temp_kf': 0,
#     'temp_max': 16.47,
#     'temp_min': 16.47},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'clear sky',
#      'icon': '01d',
#      'id': 800,
#      'main': 'Clear'}],
#    'wind': {'deg': 295, 'gust': 6.29, 'speed': 3.83}},
#   {'clouds': {'all': 79},
#    'dt': 1657616400,
#    'dt_txt': '2022-07-12 09:00:00',
#    'main': {'feels_like': 20.97,
#     'grnd_level': 1015,
#     'humidity': 48,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'temp': 21.51,
#     'temp_kf': 0,
#     'temp_max': 21.51,
#     'temp_min': 21.51},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 287, 'gust': 6.58, 'speed': 4.73}},
#   {'clouds': {'all': 76},
#    'dt': 1657627200,
#    'dt_txt': '2022-07-12 12:00:00',
#    'main': {'feels_like': 24.42,
#     'grnd_level': 1014,
#     'humidity': 34,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 24.98,
#     'temp_kf': 0,
#     'temp_max': 24.98,
#     'temp_min': 24.98},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 283, 'gust': 6.13, 'speed': 4.78}},
#   {'clouds': {'all': 72},
#    'dt': 1657638000,
#    'dt_txt': '2022-07-12 15:00:00',
#    'main': {'feels_like': 25.43,
#     'grnd_level': 1014,
#     'humidity': 32,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 25.94,
#     'temp_kf': 0,
#     'temp_max': 25.94,
#     'temp_min': 25.94},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 289, 'gust': 6.47, 'speed': 4.49}},
#   {'clouds': {'all': 62},
#    'dt': 1657648800,
#    'dt_txt': '2022-07-12 18:00:00',
#    'main': {'feels_like': 23.62,
#     'grnd_level': 1013,
#     'humidity': 38,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 24.16,
#     'temp_kf': 0,
#     'temp_max': 24.16,
#     'temp_min': 24.16},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'broken clouds',
#      'icon': '04d',
#      'id': 803,
#      'main': 'Clouds'}],
#    'wind': {'deg': 295, 'gust': 6.41, 'speed': 3.14}},
#   {'clouds': {'all': 100},
#    'dt': 1657659600,
#    'dt_txt': '2022-07-12 21:00:00',
#    'main': {'feels_like': 19.14,
#     'grnd_level': 1014,
#     'humidity': 52,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 19.75,
#     'temp_kf': 0,
#     'temp_max': 19.75,
#     'temp_min': 19.75},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04n',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 302, 'gust': 4.52, 'speed': 2.04}},
#   {'clouds': {'all': 100},
#    'dt': 1657670400,
#    'dt_txt': '2022-07-13 00:00:00',
#    'main': {'feels_like': 17.66,
#     'grnd_level': 1014,
#     'humidity': 59,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 18.24,
#     'temp_kf': 0,
#     'temp_max': 18.24,
#     'temp_min': 18.24},
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04n',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 293, 'gust': 3.89, 'speed': 1.95}},
#   {'clouds': {'all': 100},
#    'dt': 1657681200,
#    'dt_txt': '2022-07-13 03:00:00',
#    'main': {'feels_like': 17.32,
#     'grnd_level': 1014,
#     'humidity': 59,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'temp': 17.93,
#     'temp_kf': 0,
#     'temp_max': 17.93,
#     'temp_min': 17.93},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 236, 'gust': 3.75, 'speed': 2.13}},
#   {'clouds': {'all': 96},
#    'dt': 1657692000,
#    'dt_txt': '2022-07-13 06:00:00',
#    'main': {'feels_like': 19.38,
#     'grnd_level': 1013,
#     'humidity': 51,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'temp': 19.99,
#     'temp_kf': 0,
#     'temp_max': 19.99,
#     'temp_min': 19.99},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 204, 'gust': 7.25, 'speed': 3.26}},
#   {'clouds': {'all': 100},
#    'dt': 1657702800,
#    'dt_txt': '2022-07-13 09:00:00',
#    'main': {'feels_like': 20.59,
#     'grnd_level': 1012,
#     'humidity': 47,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'temp': 21.19,
#     'temp_kf': 0,
#     'temp_max': 21.19,
#     'temp_min': 21.19},
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'overcast clouds',
#      'icon': '04d',
#      'id': 804,
#      'main': 'Clouds'}],
#    'wind': {'deg': 208, 'gust': 8.78, 'speed': 3.55}}],
#  'message': 0}

# %%
# for city info Tejal

#country = response['city']['country']
#city_name = response['city']['name']

#for weather info

#weather = response['list'][0]['main']['temp']
#temp = response['list'][0]['main']
#description = response['list'][0]['weather']
#weather

# %%
list1 = json['list'][0]
list1
# Out:
# {'clouds': {'all': 75},
#  'dt': 1657281600,
#  'dt_txt': '2022-07-08 12:00:00',
#  'main': {'feels_like': 20.23,
#   'grnd_level': 1019,
#   'humidity': 64,
#   'pressure': 1009,
#   'sea_level': 1009,
#   'temp': 20.46,
#   'temp_kf': -1.97,
#   'temp_max': 22.43,
#   'temp_min': 20.46},
#  'pop': 0,
#  'sys': {'pod': 'd'},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#    'icon': '04d',
#    'id': 803,
#    'main': 'Clouds'}],
#  'wind': {'deg': 308, 'gust': 8.35, 'speed': 6.58}}

# %% [markdown]
# Now we've discovered what information we have to work with. Let's decide what we want to keep and what we wish to lose.
#
# I feel that from json['list'] it would be good to keep
#
# 'weather.main', 'weather.description', 'dt_txt', 'main.temp', 'main.feels_like' 'clouds.all', 'rain.3h', 'snow.3h' 'wind.speed', 'wind.deg', 'main.humidity', 'main.pressure'.
# And from json['city'] it would be good to keep
#
# 'name' and 'country.
# Just to make sure that we got the right place. And as an added extra we'll also include the time that API call was made, so we know how up to date our forecast is.

# %% [markdown]
# Optional: let's get a timestamp of when we get the data. Datetime uses the uses the current time of the system, which on local computers is normally correct. But as we're in the cloud, computers are not always in our country, and we therefore add on the timezone module to ensure that our timestamp is local to us and not the computer.

# %%
tz = pytz.timezone('Europe/Berlin')
now = datetime.now().astimezone(tz)

now
# Out:
# datetime.datetime(2022, 7, 8, 13, 7, 17, 151069, tzinfo=<DstTzInfo 'Europe/Berlin' CEST+2:00:00 DST>)

# %%
# we'll store the information in this dicitonary:
weather_dict = {'city': [],
                'country': [],
                'forecast_time': [],
                'outlook': [],
                'detailed_outlook': [],
                'temperature': [],
                'temperature_feels_like': [],
                'clouds': [],
                'rain': [],
                'snow': [],
                'wind_speed': [],
                'wind_deg': [],
                'humidity': [],
                'pressure': []}
                #'information_retrieved_at': []}

# let's begin the loop
for i in json['list']:
    weather_dict['city'].append(json['city']['name'])  #city and country is out of list thats why we are using json file i.e go to json file and serach it
    weather_dict['country'].append(json['city']['country'])
    weather_dict['forecast_time'].append(i['dt_txt'])
    weather_dict['outlook'].append(i['weather'][0]['main'])
    weather_dict['detailed_outlook'].append(i['weather'][0]['description'])
    weather_dict['temperature'].append(i['main']['temp'])
    weather_dict['temperature_feels_like'].append(i['main']['feels_like'])
    weather_dict['clouds'].append(i['clouds']['all'])
    # sometimes the data is missing for rain and snow. As it is not always raining or snowing
    # we cannot make a DataFrame unless the lists are all the same length, therefore missing values are bad
    # here we say try to append a value if there is one. If not, append a 0
    try:
        weather_dict['rain'].append(i['rain']['3h'])
    except:
        weather_dict['rain'].append('0')
    try:
        weather_dict['snow'].append(i['snow']['3h'])
    except:
        weather_dict['snow'].append('0')
    weather_dict['wind_speed'].append(i['wind']['speed'])
    weather_dict['wind_deg'].append(i['wind']['deg'])
    weather_dict['humidity'].append(i['main']['humidity'])
    weather_dict['pressure'].append(i['main']['pressure'])
    #weather_dict['information_retrieved_at'].append(now.strftime("%d/%m/%Y %H:%M:%S"))

# %%
weather_from_dict_df = pd.DataFrame(weather_dict)

weather_from_dict_df
# Out:
#       city country        forecast_time outlook  detailed_outlook  \
# 0   Berlin      DE  2022-07-08 12:00:00  Clouds     broken clouds
# 1   Berlin      DE  2022-07-08 15:00:00  Clouds     broken clouds
# 2   Berlin      DE  2022-07-08 18:00:00  Clouds     broken clouds
# 3   Berlin      DE  2022-07-08 21:00:00  Clouds  scattered clouds
# 4   Berlin      DE  2022-07-09 00:00:00  Clouds  scattered clouds
# 5   Berlin      DE  2022-07-09 03:00:00  Clouds  scattered clouds
# 6   Berlin      DE  2022-07-09 06:00:00  Clouds  scattered clouds
# 7   Berlin      DE  2022-07-09 09:00:00  Clouds   overcast clouds
# 8   Berlin      DE  2022-07-09 12:00:00    Rain        light rain
# 9   Berlin      DE  2022-07-09 15:00:00    Rain        light rain
# 10  Berlin      DE  2022-07-09 18:00:00  Clouds     broken clouds
# 11  Berlin      DE  2022-07-09 21:00:00  Clouds        few clouds
# 12  Berlin      DE  2022-07-10 00:00:00  Clouds  scattered clouds
# 13  Berlin      DE  2022-07-10 03:00:00  Clouds   overcast clouds
# 14  Berlin      DE  2022-07-10 06:00:00  Clouds   overcast clouds
# 15  Berlin      DE  2022-07-10 09:00:00  Clouds   overcast clouds
# 16  Berlin      DE  2022-07-10 12:00:00  Clouds   overcast clouds
# 17  Berlin      DE  2022-07-10 15:00:00  Clouds   overcast clouds
# 18  Berlin      DE  2022-07-10 18:00:00  Clouds   overcast clouds
# 19  Berlin      DE  2022-07-10 21:00:00  Clouds   overcast clouds
# 20  Berlin      DE  2022-07-11 00:00:00  Clouds     broken clouds
# 21  Berlin      DE  2022-07-11 03:00:00  Clouds     broken clouds
# 22  Berlin      DE  2022-07-11 06:00:00  Clouds     broken clouds
# 23  Berlin      DE  2022-07-11 09:00:00  Clouds   overcast clouds
# 24  Berlin      DE  2022-07-11 12:00:00    Rain        light rain
# 25  Berlin      DE  2022-07-11 15:00:00  Clouds   overcast clouds
# 26  Berlin      DE  2022-07-11 18:00:00  Clouds   overcast clouds
# 27  Berlin      DE  2022-07-11 21:00:00  Clouds   overcast clouds
# 28  Berlin      DE  2022-07-12 00:00:00  Clouds     broken clouds
# 29  Berlin      DE  2022-07-12 03:00:00   Clear         clear sky
# 30  Berlin      DE  2022-07-12 06:00:00   Clear         clear sky
# 31  Berlin      DE  2022-07-12 09:00:00  Clouds     broken clouds
# 32  Berlin      DE  2022-07-12 12:00:00  Clouds     broken clouds
# 33  Berlin      DE  2022-07-12 15:00:00  Clouds     broken clouds
# 34  Berlin      DE  2022-07-12 18:00:00  Clouds     broken clouds
# 35  Berlin      DE  2022-07-12 21:00:00  Clouds   overcast clouds
# 36  Berlin      DE  2022-07-13 00:00:00  Clouds   overcast clouds
# 37  Berlin      DE  2022-07-13 03:00:00  Clouds   overcast clouds
# 38  Berlin      DE  2022-07-13 06:00:00  Clouds   overcast clouds
# 39  Berlin      DE  2022-07-13 09:00:00  Clouds   overcast clouds
#
#     temperature  temperature_feels_like  clouds  rain snow  wind_speed  \
# 0         20.46                   20.23      75     0    0        6.58
# 1         19.85                   19.59      83     0    0        4.67
# 2         19.91                   19.55      80     0    0        4.20
# 3         16.46                   15.88      49     0    0        3.47
# 4         13.67                   13.13      39     0    0        3.68
# 5         11.75                   11.33      27     0    0        3.57
# 6         13.94                   13.50      47     0    0        3.74
# 7         17.50                   17.08     100     0    0        5.36
# 8         18.63                   18.35     100  0.81    0        5.37
# 9         20.69                   20.25      70  1.82    0        5.17
# 10        18.82                   18.06      61     0    0        6.03
# 11        14.82                   13.95      15     0    0        5.42
# 12        13.85                   12.99      27     0    0        5.20
# 13        12.90                   12.10     100     0    0        5.56
# 14        13.25                   12.41     100     0    0        5.83
# 15        16.00                   15.12      93     0    0        6.42
# 16        17.52                   16.61      96     0    0        6.30
# 17        17.29                   16.46      99     0    0        6.55
# 18        16.67                   15.91      96     0    0        5.35
# 19        15.03                   14.36      91     0    0        5.04
# 20        12.69                   12.08      54     0    0        4.13
# 21        12.26                   11.68      78     0    0        3.91
# 22        14.40                   13.80      74     0    0        4.33
# 23        19.84                   19.08      89     0    0        4.79
# 24        20.24                   19.49      90  0.25    0        4.25
# 25        21.08                   20.37      93     0    0        4.92
# 26        19.79                   19.08      86     0    0        2.39
# 27        16.00                   15.22      89     0    0        2.49
# 28        14.06                   13.27      57     0    0        2.73
# 29        12.75                   12.06       1     0    0        2.79
# 30        16.47                   15.97       6     0    0        3.83
# 31        21.51                   20.97      79     0    0        4.73
# 32        24.98                   24.42      76     0    0        4.78
# 33        25.94                   25.43      72     0    0        4.49
# 34        24.16                   23.62      62     0    0        3.14
# 35        19.75                   19.14     100     0    0        2.04
# 36        18.24                   17.66     100     0    0        1.95
# 37        17.93                   17.32     100     0    0        2.13
# 38        19.99                   19.38      96     0    0        3.26
# 39        21.19                   20.59     100     0    0        3.55
#
#     wind_deg  humidity  pressure
# 0        308        64      1009
# 1        309        65      1014
# 2        264        61      1019
# 3        295        66      1024
# 4        290        78      1024
# 5        285        90      1024
# 6        265        81      1023
# 7        270        68      1022
# 8        286        69      1020
# 9        284        55      1019
# 10       318        50      1019
# 11       308        61      1019
# 12       278        65      1019
# 13       286        71      1018
# 14       287        68      1018
# 15       299        56      1018
# 16       291        49      1018
# 17       284        53      1018
# 18       279        58      1018
# 19       284        68      1018
# 20       291        79      1018
# 21       290        82      1018
# 22       296        73      1018
# 23       304        46      1018
# 24       311        45      1018
# 25       317        43      1018
# 26       315        48      1018
# 27       314        60      1019
# 28       300        67      1020
# 29       290        76      1020
# 30       295        69      1020
# 31       287        48      1020
# 32       283        34      1019
# 33       289        32      1019
# 34       295        38      1018
# 35       302        52      1019
# 36       293        59      1019
# 37       236        59      1019
# 38       204        51      1018
# 39       208        47      1017

# %%
def get_weather_loop(cities):
    API_key = 'APIKEY'

    tz = pytz.timezone('Europe/Berlin')
    now = datetime.now().astimezone(tz)

    weather_dict = {'city': [],
                'country': [],
                'forecast_time': [],
                'outlook': [],
                'detailed_outlook': [],
                'temperature': [],
                'temperature_feels_like': [],
                'clouds': [],
                'rain': [],
                'snow': [],
                'wind_speed': [],
                'wind_deg': [],
                'humidity': [],
                'pressure': [],
                'information_retrieved_at': []}

    for city in cities:
        url = (f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_key}&units=metric")
        response = requests.get(url)
        json = response.json()
        
        for i in json['list']:
            weather_dict['city'].append(json['city']['name'])
            weather_dict['country'].append(json['city']['country'])
            weather_dict['forecast_time'].append(i['dt_txt'])
            weather_dict['outlook'].append(i['weather'][0]['main'])
            weather_dict['detailed_outlook'].append(i['weather'][0]['description'])
            weather_dict['temperature'].append(i['main']['temp'])
            weather_dict['temperature_feels_like'].append(i['main']['feels_like'])
            weather_dict['clouds'].append(i['clouds']['all'])
            try:
                weather_dict['rain'].append(i['rain']['3h'])
            except:
                weather_dict['rain'].append('0')
            try:
                weather_dict['snow'].append(i['snow']['3h'])
            except:
                weather_dict['snow'].append('0')
            weather_dict['wind_speed'].append(i['wind']['speed'])
            weather_dict['wind_deg'].append(i['wind']['deg'])
            weather_dict['humidity'].append(i['main']['humidity'])
            weather_dict['pressure'].append(i['main']['pressure'])
            weather_dict['information_retrieved_at'].append(now.strftime("%d/%m/%Y %H:%M:%S"))

    return pd.DataFrame(weather_dict)

# %%
get_weather_loop(['Berlin','Hamburg' ,'London', 'Manchester'])
# Out:
#            city country        forecast_time outlook  detailed_outlook  \
# 0        Berlin      DE  2022-07-08 12:00:00  Clouds     broken clouds
# 1        Berlin      DE  2022-07-08 15:00:00  Clouds     broken clouds
# 2        Berlin      DE  2022-07-08 18:00:00  Clouds     broken clouds
# 3        Berlin      DE  2022-07-08 21:00:00  Clouds  scattered clouds
# 4        Berlin      DE  2022-07-09 00:00:00  Clouds  scattered clouds
# ..          ...     ...                  ...     ...               ...
# 155  Manchester      GB  2022-07-12 21:00:00  Clouds   overcast clouds
# 156  Manchester      GB  2022-07-13 00:00:00  Clouds   overcast clouds
# 157  Manchester      GB  2022-07-13 03:00:00  Clouds   overcast clouds
# 158  Manchester      GB  2022-07-13 06:00:00  Clouds   overcast clouds
# 159  Manchester      GB  2022-07-13 09:00:00    Rain        light rain
#
#      temperature  temperature_feels_like  clouds  rain snow  wind_speed  \
# 0          20.43                   20.17      75     0    0        6.58
# 1          19.83                   19.57      83     0    0        4.67
# 2          19.90                   19.54      80     0    0        4.20
# 3          16.46                   15.88      49     0    0        3.47
# 4          13.67                   13.13      39     0    0        3.68
# ..           ...                     ...     ...   ...  ...         ...
# 155        19.87                   19.53      99     0    0        1.14
# 156        19.21                   19.04      99     0    0        1.67
# 157        17.83                   18.02      96     0    0        2.57
# 158        17.84                   17.95      98     0    0        2.91
# 159        20.10                   20.12     100  0.13    0        3.66
#
#      wind_deg  humidity  pressure information_retrieved_at
# 0         308        63      1008      08/07/2022 13:07:17
# 1         309        65      1014      08/07/2022 13:07:17
# 2         264        61      1019      08/07/2022 13:07:17
# 3         295        66      1024      08/07/2022 13:07:17
# 4         290        78      1024      08/07/2022 13:07:17
# ..        ...       ...       ...                      ...
# 155       266        62      1016      08/07/2022 13:07:17
# 156       273        71      1016      08/07/2022 13:07:17
# 157       267        90      1016      08/07/2022 13:07:17
# 158       269        87      1016      08/07/2022 13:07:17
# 159       278        75      1016      08/07/2022 13:07:17
#
# [160 rows x 15 columns]
